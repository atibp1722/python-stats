# %%
import pandas as pd

# %%
data=pd.read_csv('EPL_Set.csv')
data.tail(15)
# Out:
#      Div       Date        HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 9649  E0   9/5/2018         Chelsea  Huddersfield     1     1   D   0.0   0.0
# 9650  E0   9/5/2018       Leicester       Arsenal     3     1   H   1.0   0.0
# 9651  E0   9/5/2018        Man City      Brighton     3     1   H   2.0   1.0
# 9652  E0   9/5/2018       Tottenham     Newcastle     1     0   H   0.0   0.0
# 9653  E0  10/5/2018        West Ham    Man United     0     0   D   0.0   0.0
# 9654  E0   13/05/18         Burnley   Bournemouth     1     2   A   1.0   0.0
# 9655  E0   13/05/18  Crystal Palace     West Brom     2     0   H   0.0   0.0
# 9656  E0   13/05/18    Huddersfield       Arsenal     0     1   A   0.0   1.0
# 9657  E0   13/05/18       Liverpool      Brighton     4     0   H   2.0   0.0
# 9658  E0   13/05/18      Man United       Watford     1     0   H   1.0   0.0
# 9659  E0   13/05/18       Newcastle       Chelsea     3     0   H   1.0   0.0
# ...

# %%
data.count()
# Out:
# Div         9664
# Date        9664
# HomeTeam    9664
# AwayTeam    9664
# FTHG        9664
# FTAG        9664
# FTR         9664
# HTHG        8740
# HTAG        8740
# HTR         8740
# Season      9664
# dtype: int64

# %%
set(data['FTR'])
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data['HTR'].unique()
# Out:
# array([nan, 'H', 'D', 'A'], dtype=object)

# %%
season=data.groupby('Season')
season.first()
season.get_group('2017-18')
# Out:
#      Div       Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 9284  E0  11/8/2017         Arsenal       Leicester     4     3   H   2.0
# 9285  E0  12/8/2017        Brighton        Man City     0     2   A   0.0
# 9286  E0  12/8/2017         Chelsea         Burnley     2     3   A   0.0
# 9287  E0  12/8/2017  Crystal Palace    Huddersfield     0     3   A   0.0
# 9288  E0  12/8/2017         Everton           Stoke     1     0   H   1.0
# 9289  E0  12/8/2017     Southampton         Swansea     0     0   D   0.0
# 9290  E0  12/8/2017         Watford       Liverpool     3     3   D   2.0
# 9291  E0  12/8/2017       West Brom     Bournemouth     1     0   H   1.0
# 9292  E0   13/08/17      Man United        West Ham     4     0   H   1.0
# 9293  E0   13/08/17       Newcastle       Tottenham     0     2   A   0.0
# 9294  E0   19/08/17     Bournemouth         Watford     0     2   A   0.0
# 9295  E0   19/08/17         Burnley       West Brom     0     1   A   0.0
# ...

# %%
season_first=data.groupby(['HomeTeam','AwayTeam','Season'])
season_first.first()
# Out:
#                                Div        Date  FTHG  FTAG FTR  HTHG  HTAG  \
# HomeTeam AwayTeam      Season
# Arsenal  Aston Villa   1993-94  E0   6/11/1993     1     2   A   NaN   NaN
#                        1994-95  E0    26/12/94     0     0   D   NaN   NaN
#                        1995-96  E0    21/10/95     2     0   H   0.0   0.0
#                        1996-97  E0    28/12/96     2     2   D   1.0   0.0
#                        1997-98  E0    26/10/97     0     0   D   0.0   0.0
#                        1998-99  E0    16/05/99     1     0   H   0.0   0.0
#                        1999-00  E0   11/9/1999     3     1   H   1.0   1.0
#                        2000-01  E0    14/10/00     1     0   H   0.0   0.0
#                        2001-02  E0   9/12/2001     3     2   H   0.0   2.0
#                        2002-03  E0  30/11/2002     3     1   H   1.0   0.0
#                        2003-04  E0    27/08/03     2     0   H   0.0   0.0
# ...

# %%
seasons=data.groupby('Season')
for team, info in seasons:
    print('First 2 entries for', season)
    print("")
    print(info.head(2))
# Out:
# ('First 2 entries for', <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0B60C4D0>)
#
#   Div      Date     HomeTeam  AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  HTR  \
# 0  E0  14/08/93      Arsenal  Coventry     0     3   A   NaN   NaN  NaN
# 1  E0  14/08/93  Aston Villa       QPR     4     1   H   NaN   NaN  NaN
#
#     Season
# 0  1993-94
# 1  1993-94
# ('First 2 entries for', <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0B60C4D0>)
#
#     Div      Date HomeTeam  AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  HTR   Season
# 462  E0  20/08/94  Arsenal  Man City     3     0   H   NaN   NaN  NaN  1994-95
# 463  E0  20/08/94  Chelsea   Norwich     2     0   H   NaN   NaN  NaN  1994-95
# ('First 2 entries for', <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0B60C4D0>)
#
#     Div      Date     HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 924  E0  19/08/95  Aston Villa  Man United     3     1   H   3.0   0.0   H
# ...
